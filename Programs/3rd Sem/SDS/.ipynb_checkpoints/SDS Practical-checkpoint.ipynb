# %%
import pandas as pd
import seaborn as sb
import nummpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("BKB.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9f8ef618eb6c> in <module>
#       1 import pandas as pd
#       2 import seaborn as sb
# ----> 3 import nummpy as np
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'nummpy'

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("BKB.csv")
data.head()
# Out:
#    Applicant ID         Loan Type Gender Marital Status Accomodation Type  \
# 0             1         Home Loan   Male        Married      Family Other
# 1             2         Home Loan   Male        Married      Family Other
# 2             3         Home Loan   Male        Married  Company Provided
# 3             4  Home Improvement   Male        Married             Owned
# 4             5         Home Loan   Male        Married      Family Other
#
#    No of years in the current address  No. of Years in the current job  \
# 0                                  32                                7
# 1                                   3                               17
# 2                                   7                                8
# 3                                  15                                7
# 4                                   4                               10
#
#    Monthly Salary  Balance in Savings Account  Loan Amount Requested  Term  \
# 0            8000                        1406                 500000   120
# 1           30000                       42235                1000000   180
# 2            8000                       15217                 700000   120
# 3           20462                       29551                 250000    84
# 4           13534                        2056                 400000   180
#
#    Down Payment   EMI Affordable
# 0         700000             8690
# 1         300000            16000
# 2         955000            15000
# 3         250000             5856
# 4         700000             6157

# %%
simple_random_sample = data.sample(n=100)
simple_random_sample
# Out:
#       Applicant ID  Loan Type Gender Marital Status Accomodation Type  \
# 2511          2512  Home Loan   Male        Married             Owned
# 3093          3094  Home Loan   Male        Married      Family Other
# 592            593  Home Loan   Male        Married  Company Provided
# 454            455  Home Loan   Male         Single            Rented
# 780            781  Home Loan   Male        Married             Owned
# ...            ...        ...    ...            ...               ...
# 1648          1649  Home Loan   Male        Married             Owned
# 2593          2594  Home Loan   Male        Married      Family Other
# 387            388  Home Loan   Male        Married            Rented
# 1959          1960  Home Loan   Male        Married             Owned
# 2104          2105  Home Loan   Male        Married      Family Other
#
#       No of years in the current address  No. of Years in the current job  \
# 2511                                   9                               30
# 3093                                  25                               10
# 592                                    6                                6
# 454                                    6                                4
# 780                                    1                               15
# ...                                  ...                              ...
# 1648                                  12                               12
# 2593                                  35                               18
# 387                                    5                                3
# 1959                                  36                               36
# 2104                                  10                               15
#
#       Monthly Salary  Balance in Savings Account  Loan Amount Requested  Term  \
# 2511           30000                         574                 800000   180
# 3093           14600                        1677                 300000   180
# 592             8000                        1072                 500000   180
# 454            22000                         448                1000000   180
# 780             8500                       39021                 300000   180
# ...              ...                         ...                    ...   ...
# 1648           15000                        1000                1000000   180
# 2593           17500                       40207                 300000   180
# 387            58207                       48517                 800000   180
# 1959           17129                       19704                 300000   120
# 2104           15000                         500                 800000   180
#
#       Down Payment   EMI Affordable
# 2511         350000            11752
# 3093         231000             4618
# 592          700000             7695
# 454          330000            22000
# 780          475000             4618
# ...             ...              ...
# 1648         500000            15000
# 2593         220000             4618
# 387         3400000            15000
# 1959         900000             7000
# 2104         200000            13000
#
# [100 rows x 13 columns]

# %%
def systematic_sampling(df,step):
    indexes = np.arange(0,len(df),step = step)
    systematic_sample = df.iloc[indexes]
    return systematic_sample

systematic_sample = systematic_sampling(data,350)
systematic_sample
# Out:
#       Applicant ID         Loan Type  Gender Marital Status Accomodation Type  \
# 0                1         Home Loan    Male        Married      Family Other
# 350            351         Home Loan    Male        Married            Rented
# 700            701         Home Loan    Male        Married      Family Other
# 1050          1051         Home Loan  Female        Married            Rented
# 1400          1401         Home Loan    Male        Married            Rented
# 1750          1751         Home Loan  Female        Married            Rented
# 2100          2101  Home Improvement  Female        Married             Owned
# 2450          2451         Home Loan    Male        Married            Rented
# 2800          2801         Home Loan    Male        Married            Rented
# 3150          3151         Home Loan    Male        Married            Rented
# 3500          3501         Home Loan    Male        Married            Rented
# 3850          3851         Home Loan    Male        Married            Rented
#
#       No of years in the current address  No. of Years in the current job  \
# 0                                     32                                7
# 350                                    3                                3
# 700                                   20                                9
# 1050                                   8                                3
# 1400                                   1                                1
# 1750                                   8                                8
# 2100                                  23                               20
# 2450                                   1                               15
# 2800                                   2                               22
# 3150                                   9                               18
# 3500                                   2                                6
# 3850                                   2                                4
#
#       Monthly Salary  Balance in Savings Account  Loan Amount Requested  Term  \
# 0               8000                        1406                 500000   120
# 350            10000                       14594                 700000   180
# 700            20000                           0                 800000   180
# 1050           18000                       32312                 600000   180
# 1400           46968                       63177                 800000   180
# 1750           28990                       39944                 800000   180
# 2100           10000                        2500                 100000    84
# 2450           50000                       60000                 400000   180
# 2800           20000                        1103                 300000   180
# 3150           17300                        1022                 350000   180
# 3500           12000                       31419                 400000   180
# 3850           28334                         500                 800000   132
#
#       Down Payment   EMI Affordable
# 0            700000             8690
# 350          300000            15000
# 700          200000            12313
# 1050         320000            10000
# 1400         200000            14000
# 1750         351000            13000
# 2100         900000             4000
# 2450         100000            30000
# 2800         180000             4618
# 3150         150000             6000
# 3500         141750             7000
# 3850         200000            15000

# %%
dataTypeSeries = data.dtypes
print('Data type of each column of data')
print(dataTypeSeries)
# Out:
# Data type of each column of data
# Applicant ID                           int64
# Loan Type                             object
# Gender                                object
# Marital Status                        object
# Accomodation Type                     object
# No of years in the current address     int64
# No. of Years in the current job        int64
# Monthly Salary                         int64
# Balance in Savings Account             int64
# Loan Amount Requested                  int64
# Term                                   int64
# Down Payment                           int64
# EMI Affordable                         int64
# dtype: object

# %%
print("No. Of Years                 ", int(data["No of years in the current address"].mean()))
print("Monthly Salary               ", data["Monthly Salary"].median())
# Out:
# No. Of Years                  10
# Monthly Salary                19000.0

# %%
data.describe()
# Out:
#        Applicant ID  No of years in the current address  \
# count   3864.000000                         3864.000000
# mean    1932.500000                           10.600414
# std     1115.585048                           10.905176
# min        1.000000                            0.000000
# 25%      966.750000                            2.000000
# 50%     1932.500000                            6.000000
# 75%     2898.250000                           15.000000
# max     3864.000000                           92.000000
#
#        No. of Years in the current job  Monthly Salary  \
# count                      3864.000000     3864.000000
# mean                         10.926501    22618.984472
# std                           8.086977    19783.322389
# min                           0.000000        0.000000
# 25%                           5.000000    12200.750000
# 50%                          10.000000    19000.000000
# 75%                          15.000000    28500.000000
# max                          65.000000   500000.000000
#
#        Balance in Savings Account  Loan Amount Requested         Term  \
# count                3.864000e+03            3864.000000  3864.000000
# mean                 3.158295e+04          609055.261905   160.158126
# std                  1.274989e+05          245075.074723    37.995737
# min                  0.000000e+00           50000.000000    15.000000
# 25%                  1.500000e+03          400000.000000   180.000000
# 50%                  6.357500e+03          600000.000000   180.000000
# 75%                  2.500000e+04          800000.000000   180.000000
# max                  5.388413e+06         1000000.000000   180.000000
#
#        Down Payment   EMI Affordable
# count   3.864000e+03     3.864000e+03
# mean    4.274711e+05     1.288153e+04
# std     6.380023e+05     3.295702e+04
# min     0.000000e+00     8.400000e+01
# 25%     2.000000e+05     7.696000e+03
# 50%     3.000000e+05     1.077400e+04
# 75%     5.000000e+05     1.500000e+04
# max     1.700000e+07     1.200000e+06

# %%
sb.barplot(x = "Gender",y = "No. of Years in the current job",data=data)
# Out:
# <AxesSubplot:xlabel='Monthly Salary', ylabel='No. of Years in the current job'>
